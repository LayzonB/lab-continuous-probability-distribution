# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %%
from scipy.stats import uniform
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import expon
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#from statsmodels.graphics.gofplots import qqplot
#qqplot(vehicles['CO2 Emission Grams/Mile'], line ='s')

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.94035182 2.3809762  2.91808764 2.37151865 2.61909528 2.69387243
#  2.58964888 2.82981527 2.23082014 2.84989831]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
bottom=10
ceiling=15
count=100
x = uniform.rvs(size=count)

randoms  = bottom + (ceiling-bottom)*x
print(randoms)
# Out:
# [13.28870413 14.56402987 12.190301   14.59798303 10.74740088 13.57563889
#  14.99863238 14.28263054 14.77486673 10.77568402 11.95868214 13.05378524
#  12.34693216 14.5683675  11.34940847 14.30619976 11.86589981 12.72293337
#  10.97454427 11.59976468 12.44305391 12.66846405 12.72058259 13.9631838
#  14.72682485 10.69992097 11.82035597 10.66437537 13.29205831 12.55040843
#  12.97905247 11.062133   12.35063214 14.73394856 13.64974552 12.3034401
#  11.27708189 10.12014952 14.48387014 11.74768365 10.30207946 14.29153211
#  13.80129764 13.35542379 11.20750538 12.18050207 13.19905049 14.38976028
#  11.498536   12.06555359 14.05135155 11.34523639 11.87022093 10.72330635
#  14.69683707 13.07980634 10.3661305  13.20953814 13.07626931 12.3437735
#  14.9717233  12.36793912 13.84715538 13.98811148 13.59189925 12.81085156
#  14.55645393 10.55837904 10.2623775  10.51842323 13.68358895 11.0494941
#  13.51888293 11.21290741 13.31865701 12.59327433 11.7439957  14.00029388
# ...

# %% [markdown]
# How are the two distributions different?

# %%
fig, ax = plt.subplots(1,2, sharey = True)

ax[0].hist(randoms, bins=10)
# Out:
# (array([ 8.,  9.,  9., 12., 10.,  8., 12., 11.,  8., 13.]),
#  array([10.12014952, 10.6079978 , 11.09584609, 11.58369438, 12.07154266,
#         12.55939095, 13.04723924, 13.53508752, 14.02293581, 14.5107841 ,
#         14.99863238]),
#  <a list of 10 Patch objects>)

# %%
def uniform_dist(bottom, ceiling, count):
    x = uniform.rvs(size = count)
    rand_1  = bottom + ((ceiling - bottom) * x)
    return(rand_1)

group1 = uniform_dist(10, 15,100)
group2 = uniform_dist(10, 60,1000)

fig, ax = plt.subplots(1,2, sharey = True, figsize = (12, 8))


ax[0].hist(group1, bins=10)
ax[1].hist(group2, bins=10);

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(10,15, 100)
ax.plot(x, uniform.pdf(x))

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(10,60, 1000)
ax.plot(x, uniform.pdf(x))

# %%
# your answer below
#In both cases the probability is constant

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
def normal(mean,std,size):
    return(norm.rvs(loc = mean, scale = std, size=size))

#norm_dis1 = normal(10, 1, 1000)
#norm_dis2 = normal(10, 50, 1000)

fig, ax = plt.subplots(1,2, sharey = True)
ax[0].hist(normal(10, 1, 1000), bins=50)
ax[1].hist(normal(10, 50, 1000), bins=50);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# more standar dev, more separated from the mean the data

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles=pd.read_csv("vehicles.csv")

# %%
# your code here
plt.hist(vehicles["Fuel Barrels/Year"],bins=10,facecolor="g");

# %%
print(vehicles["Fuel Barrels/Year"].describe(),\
    vehicles["Fuel Barrels/Year"].mode(),\
    vehicles["Fuel Barrels/Year"].median())
# Out:
# count    35952.000000
# mean        17.609056
# std          4.467283
# min          0.060000
# 25%         14.699423
# 50%         17.347895
# 75%         20.600625
# max         47.087143
# Name: Fuel Barrels/Year, dtype: float64 0    18.311667
# dtype: float64 17.347894736842107

# %%
sns.distplot(vehicles['Fuel Barrels/Year'],bins = 50)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.hist(vehicles['CO2 Emission Grams/Mile'], bins = 10);

# %%
print(vehicles['CO2 Emission Grams/Mile'].describe(),\
    vehicles['CO2 Emission Grams/Mile'].mode(),\
    vehicles['CO2 Emission Grams/Mile'].median())
# Out:
# count    35952.000000
# mean       475.316339
# std        119.060773
# min         37.000000
# 25%        395.000000
# 50%        467.736842
# 75%        555.437500
# max       1269.571429
# Name: CO2 Emission Grams/Mile, dtype: float64 0    493.722222
# dtype: float64 467.73684210526324

# %% [markdown]
# 3. Combined MPG

# %%
sns.distplot(vehicles["Combined MPG"],bins = 50)

# %%
print(vehicles["Combined MPG"].describe(),\
    vehicles["Combined MPG"].mode(),\
    vehicles["Combined MPG"].median())
# Out:
# count    35952.000000
# mean        19.929322
# std          5.112409
# min          7.000000
# 25%         16.000000
# 50%         19.000000
# 75%         23.000000
# max         56.000000
# Name: Combined MPG, dtype: float64 0    18
# dtype: int64 19.0

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
#"Combined MPG" looks more symmetrical about the mean, but is not a definitive

#from Kamala, #https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/
# use quantile- quantile plot qqplot to look after deviations

# %%
qqplot(vehicles['Fuel Barrels/Year'], line='s')

# %%
qqplot(vehicles['CO2 Emission Grams/Mile'], line ='s')

# %%
qqplot(vehicles['Combined MPG'], line='s')

# %%
#in this case non of the selected columns has full formal distribution

# %%
"""
from scipy.stats import anderson
# normality test
def check_normal(data):
    result = anderson(data)
    #print('Statistic: %.3f' % result.statistic)
    p = 0
#     for i in range(len(result.critical_values)):
#         sl, cv = result.significance_level[i], result.critical_values[i]
#         if result.statistic < result.critical_values[i]:
#             print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
#         else:
#             print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
    # 5% confidence level
    sl, cv = result.significance_level[2], result.critical_values[2]
    if result.statistic < cv:
        return "Data looks Normal"
    else:
        return "Data does not look Normal"

print('Combined MPG:', check_normal(vehicles['Combined MPG']))
print('CO2 Emission Grams/Mile:', check_normal(vehicles['CO2 Emission Grams/Mile']))
print('Fuel Barrels/Year:', check_normal(vehicles['Fuel Barrels/Year']))

"""

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exp(average, count):
    return np.random.exponential(size= count, scale= average)

set_1= exp(1, 1000)
set_2= exp(100, 1000)
fig, ax= plt.subplots(1, 2, figsize=(12, 8), sharey=True)
ax[0].hist(set_1, bins=100)
ax[1].hist(set_2, bins=100);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
p = expon.cdf(14, scale = 10)
print(p)
# Out:
# 0.7534030360583935

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
1-p
# Out:
# 0.24659696394160646
